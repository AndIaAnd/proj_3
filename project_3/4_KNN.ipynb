# %% [markdown]
# Алгоритм KNN — надежный, простой и популярный метод машинного обучения. Несмотря на простоту реализации, это конкурентоспособная и быстрая методика машинного обучения. Во всех прочих моделях машинного обучения, обсуждавшихся выше, обучающие данные использовались для вычисления представления исходных данных, на основе которого затем можно будет предсказывать, классифицировать или кластеризовать новые данные. Например, в алгоритмах линейной и логистической регрессии описываются параметры обучения, в то время как в алгоритме кластеризации вычисляются центры кластеров, исходя из обучающих данных. Алгоритм KNN отличается в этом отношении. В отличие от других подходов, в нем не вычисляется новая модель (или представление), а используется в качестве модели весь набор данных целиком.
# Да, все правильно. Модель машинного обучения — всего лишь набор наблюдений. Каждый элемент обучающих данных — часть модели. У такого подхода есть свои преимущества и недостатки. Неудобен он тем, что размеры модели могут резко увеличиваться с ростом объема обучающих данных, а значит, может понадобиться предварительный этап обработки — фильтрации или выборки. Большое преимущество его, впрочем, в относительной простоте этапа обучения (достаточно просто добавить в модель новые значения данных). Кроме того, алгоритм KNN можно использовать как для предсказания, так и для классификации. При заданном входном векторе x алгоритм выглядит следующим образом.
# 1.
# Найти k ближайших соседей x (в соответствии с заранее выбранной метрикой расстояния).
# 2.
# Агрегировать k ближайших соседей в одно значение предсказания или классификации. При этом может использоваться любая агрегирующая функция, например взятие среднего, максимального или минимального значения.
# Посмотрим для примера на компанию, торгующую недвижимостью. У нее есть большая база покупателей и цен на дома. В один прекрасный момент клиент спрашивает, сколько может стоить дом площадью 52 м2. Вы запрашиваете свою модель KNN и немедленно получаете ответ: 33 167 долларов. И действительно, в ту же неделю клиент находит дом за 33 489 долларов. Как же системе KNN удалось произвести настолько безошибочное предсказание?

# %%
from sklearn.neighbors import KNeighborsRegressor
import numpy as np
## Данные (площадь дома (в квадратных метрах) / цена дома ($))
X = np.array([[35, 30000], [45, 45000], [40, 50000],
[35, 35000], [25, 32500], [40, 40000],[35, 30000], [45, 45000], [40, 50000],
[35, 35000], [25, 32500], [40, 40000],[35, 30000], [45, 45000], [40, 50000],
[35, 35000], [25, 32500], [40, 40000], [35, 30000], [45, 45000], [40, 50000],
[35, 35000], [25, 32500], [40, 40000], [35, 30000], [45, 45000], [40, 50000],
[35, 35000], [25, 32500], [40, 40000],[35, 30000], [45, 45000], [40, 50000],
[35, 35000], [25, 32500], [40, 40000],[35, 30000], [45, 45000], [40, 50000],
[35, 35000], [25, 32500], [40, 40000], [35, 30000], [45, 45000], [40, 50000],
[35, 35000], [25, 32500], [35, 30000], [45, 45000], [40, 50000],
[35, 35000], [25, 32500], [40, 40000],[35, 30000], [45, 45000], [40, 50000],
[35, 35000], [25, 32500], [40, 40000],[35, 30000], [45, 45000], [40, 50000],
[35, 35000], [25, 32500], [40, 40000], [35, 30000], [45, 45000], [40, 50000],
[35, 35000], [25, 32500], [35, 30000], [45, 45000], [40, 50000],
[35, 35000], [25, 32500], [40, 40000],[35, 30000], [45, 45000], [40, 50000],
[35, 35000], [25, 32500], [40, 40000],[35, 30000], [45, 45000], [40, 50000],
[35, 35000], [25, 32500], [40, 40000], [35, 30000], [45, 45000], [40, 50000],
[35, 35000], [25, 32500], [35, 30000], [45, 45000], [40, 50000],
[35, 35000], [25, 32500], [40, 40000],[35, 30000], [45, 45000], [40, 50000],
[35, 35000], [25, 32500], [40, 40000],[35, 30000], [45, 45000], [40, 50000],
[35, 35000], [25, 32500], [40, 40000], [35, 30000], [45, 45000], [40, 50000],
[35, 35000], [25, 32500],])
KNN = KNeighborsRegressor(n_neighbors=3).fit(X[:,0].reshape(-1, 1), X[:,1])
''' 
закоменченные функции нужны были для того, что бы корректно отобразить график
тоесть, я хотел взять длину всего массива и его максимум, создав новый массив,
размером с исходный по столбцам, положить в него максимум из возможных значений,
таким образом, создав новый массив (вектор), его можно было использовать для отображения
графика с помощью функции plot, она в свою очередь требует два вектора А и Б, одинаковых значений
тут я использовал соотвествующие функции для создания такого вектора.
Но оказалось все проще, можно было просто получить входное значение
передать его на scatter и получить нормальный график, но на будущее оставлю эту логику
пару раз чуть мозг не сгорел :)))
#a, b  = len(X),np.max(X)
#x_max = np.array([(x, y) for x in range(a) for y in range(1)]) 
#x_max[-1:,-1:] += [b] 
#print(x_max)
'''

b = int(input("Введите пожалуйста колличевство квадратов")) # подаем на вход желаемое колличевство квадратов
res = KNN.predict([[b]])
print(f"В соотвествии с нашей моделью цена на {b} квадратов составит ~= {res} $ ")
res = int(res) # преобразуем что бы использовать в графике 
a_price , b_price = np.max(X), np.min(X)
# Out:
# В соотвествии с нашей моделью цена на 35 квадратов составит ~= [33333.33333333] $

# %%
import matplotlib.pyplot as plt 
#max_m = int(np.max(X)/np.max(X[:,:-1])) # все хуйня 
#min_m = int(np.min(X[:,1:])/np.min(X[:,:-1]))
plt.style.use('seaborn')
plt.plot(X[:,1:],  color= 'green', linestyle=':', 
        label = f'средняя квадратура {int(np.average(X[:,:-1]))} m^2,\nсредняя цена {int(np.average(X[:,-1:]))} \$ \nсредняя цена за м^2~= {int(np.average(X[:,-1:])/np.average(X[:,:-1]))}\$ ')
plt.scatter(b,res,color = 'blue', marker= 'p', 
        label = f'price predict модели(X) = {res},\ninput from user m^2(Y) = {b} ')
plt.minorticks_on() 
plt.ylabel('price')
plt.xlabel('m*2')
plt.legend(loc='upper right', labelcolor = 'Crimson')

plt.show()
#по иксу отображается колличевство датасетов(тоесть единиц [[]])

# %%
'''
#a1 = [x for x in X if x == 50000] # 

#a = X[np.sort(X.all(), axis= 0)]
#print(a)
a = np.max(X)/ np.max(X[:,:-1])  # это 45
print() 
print(a)
print(int(np.min(X[:,1:])/np.min(X[:,:-1])))
здесь я пытаюсь сделать прикольную штуку, типа получать индексы 
максимальных цен и сразу выводить площадь соотвествующую этим индексам
'''
# Out:
# '\n#a1 = [x for x in X if x == 50000] # \n\n#a = X[np.sort(X.all(), axis= 0)]\n#print(a)\na = np.max(X)/ np.max(X[:,:-1])  # это 45\nprint() \nprint(a)\nprint(int(np.min(X[:,1:])/np.min(X[:,:-1])))\nздесь я пытаюсь сделать прикольную штуку, типа получать индексы \nмаксимальных цен и сразу выводить площадь соотвествующую этим индексам\n'
